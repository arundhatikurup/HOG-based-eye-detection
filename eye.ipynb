# %%
import os
import numpy 
import cv2
from matplotlib import pyplot as plt
from PIL import Image

face_cascade = cv2.CascadeClassifier('/home/arundhati/cv/dlib_project/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('/home/arundhati/cv/dlib_project/haarcascade_eye.xml')

# %%
image_rootDir="/home/arundhati/cv/dlib_project/orl_faces"
for dirName, subdirList, fileList in os.walk(image_rootDir):
        for fname in fileList:
            if fname.endswith(('.pgm')):
                #p1=[]
                label=os.path.basename(dirName)
                image_path = os.path.join(dirName, fname)
                image_pil = Image.open(image_path).convert('L')
                image = numpy.array(image_pil, 'uint8')
                cv2.imshow("image",image)
                cv2.waitKey(25)
                faces = face_cascade.detectMultiScale(image,1.1, 5)
                try:
                    for (x,y,w,h) in faces:
                        roi_gray = image[y:y+h, x:x+w]
                        cv2.imwrite("/home/arundhati/cv/dlib_project/eyes/" +fname + ".jpg",roi_gray)
                        eyes = eye_cascade.detectMultiScale(roi_gray)
                        for (ex,ey,ew,eh) in eyes:
                            eye_gray=image[ey:ey+eh,ex:ex+ew]
                            cv2.imwrite("/home/arundhati/cv/dlib_project/eyes/" + fname + ".jpg",eye_gray)
                except TypeError: 
                    print fname
                    continue

# %%
path = '/home/arundhati/cv/dlib_project/faces' 

image_paths = [os.path.join(path, f) for f in os.listdir(path)]

for image_path in image_paths:
    image_pil = Image.open(image_path).convert('L')
    image = numpy.array(image_pil, 'uint8')
    cv2.imshow("image",image)
    cv2.waitKey(25)
    faces = face_cascade.detectMultiScale(image,1.1, 5)
    try:
        for (x,y,w,h) in faces:
            roi_gray = image[y:y+h, x:x+w]
            cv2.imwrite("/home/arundhati/cv/dlib_project/look/" +image_path + ".jpg",roi_gray)
            eyes = eye_cascade.detectMultiScale(roi_gray)
            for (ex,ey,ew,eh) in eyes:
                    eye_gray=image[ey:ey+eh,ex:ex+ew]
                    cv2.imwrite("/home/arundhati/cv/dlib_project/eyes/" +image_path + ".jpg",eye_gray)
    except TypeError: 
        print image_path
        continue

# %%
import cv2

face_cascade = cv2.CascadeClassifier('/home/arundhati/cv/dlib_project/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('/home/arundhati/cv/dlib_project/haarcascade_eye.xml')

img = cv2.imread("/home/arundhati/cv/dlib_project/dump/27.jpg" )
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray,1.1, 5)
    
for (x,y,w,h) in faces:
        f=[]
        roi_gray = gray[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        for (ex,ey,ew,eh) in eyes:
            v=[ex,ey,ew,eh]
            f.append(v)
        eye_gray=roi_gray[63:113,45:188]
        cv2.imwrite("/home/arundhati/cv/dlib_project/eyes/" + str(2) + ".jpg",eye_gray)
            
        print f
# Out:
# [[138, 63, 50, 50], [124, 139, 22, 22], [45, 71, 48, 48]]

# %%
import os
import numpy 
import cv2
from matplotlib import pyplot as plt
from PIL import Image

face_cascade = cv2.CascadeClassifier('/home/arundhati/cv/dlib_project/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('/home/arundhati/cv/dlib_project/haarcascade_eye.xml')



path = '/home/arundhati/cv/dlib_project/faces' 

image_paths = [os.path.join(path, f) for f in os.listdir(path)]

for image_path in image_paths:
    image_pil = Image.open(image_path).convert('L')
    image = numpy.array(image_pil, 'uint8')
    #cv2.imshow("image",image)
    #cv2.waitKey(25)
    faces = face_cascade.detectMultiScale(image,1.1, 5)
    try:
        f=[]
        for (x,y,w,h) in faces:
            v=[]
            roi_gray = image[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray)
            for (ex,ey,ew,eh) in eyes:
                    v= [ex,ey,ew,eh]
                    f.append(v) 
                    print f
            eye_gray=roi_gray[f[0][1]:f[0][1]+f[0][2],f[0][0]:f[0][0]+f[0][2]]
            cv2.imwrite("/home/arundhati/cv/dlib_project/look/" +image_path + ".jpg",eye_gray)
    except TypeError: 
        print image_path
        continue

# %% [markdown]
# FINAL

# %%
def get_landmarks1(im):
    try:
        rects = detector(im, 1)	
        a=numpy.array([[p.x, p.y] for p in predictor(im, rects[0]).parts()])
    except IndexError :
        pass

    else :
        return a

# %%
import cv2 , os
import dlib
import numpy 
import matplotlib.pyplot as plt
from PIL import Image

PREDICTOR_PATH = "/home/arundhati/cv/dlib_project/shape_predictor_68_face_landmarks.dat/data"

predictor = dlib.shape_predictor(PREDICTOR_PATH)
detector = dlib.get_frontal_face_detector()

# %%
image_rootDir="/home/arundhati/cv/dlib_project/orl_faces"
i=0
for dirName, subdirList, fileList in os.walk(image_rootDir):
        for fname in fileList:
            if fname.endswith(('.pgm')):
                p1=[]
                label=os.path.basename(dirName)
                image_path = os.path.join(dirName, fname)
                #print image_path
                image_pil = Image.open(image_path).convert('L')
                image = numpy.array(image_pil, 'uint8')
                try:
                    landmarks1=get_landmarks1(image)
                    x1,y1=landmarks1[17]
                    x2,y2=landmarks1[19]
                    x3,y3=landmarks1[26]
                    x4,y4=landmarks1[29]
                    print x1,y1,x2,y2,x3,y3,x4,y4
                    w=x3-x1
                    h=y4-y2
                    crop=image[y2:y2+h,x1:x1+w]
                    cv2.imwrite("/home/arundhati/cv/dlib_project/look/" +str(i+1) + ".jpg",crop)
                    i=i+1
                    
                except TypeError: 
                    print fname
                    continue
# Out:
# 8 57 21 51 79 58 44 75
# 14 60 28 55 83 60 51 77
# 21 61 35 56 82 60 59 80
# 19 58 34 53 83 59 56 77
# 11 57 22 54 71 62 38 78
# 15 56 27 52 77 60 46 77
# 4 55 12 52 65 61 24 77
# 14 49 26 42 79 51 47 62
# 13 59 26 55 78 62 45 79
# 20 57 36 52 82 56 60 76
# 7 43 19 33 80 37 45 57
# 5 48 14 38 69 38 35 57
# 12 46 24 38 79 40 50 59
# 10 46 22 38 81 41 48 60
# 7 44 20 35 80 40 45 57
# 3 44 14 35 74 38 38 57
# 8 44 20 34 76 37 45 55
# 6 42 17 32 73 35 41 55
# 12 45 23 36 77 40 47 59
# 8 40 20 28 79 34 46 47
# 22 58 35 53 83 54 59 71
# 5 54 14 49 67 53 29 67
# 5 55 18 50 76 53 40 68
# 16 57 30 53 81 55 52 70
# 11 54 22 48 74 54 42 65
# 24 54 37 48 84 51 62 65
# 7 55 14 49 65 54 26 67
# 8 56 17 49 71 50 36 65
# 23 57 36 50 83 51 62 66
# 5 55 13 50 65 55 28 69
# 0 56 8 51 61 54 24 69
# 3 54 12 50 64 54 29 69
# 2 52 8 47 59 52 23 66
# 18 56 31 49 80 54 53 67
# 3 54 11 48 64 53 29 67
# 14 53 25 48 76 55 45 67
# 11 56 21 52 70 56 38 71
# 9 52 17 44 70 49 37 60
# 10 57 22 54 72 59 39 74
# 3 54 10 48 62 52 27 66
# 11 37 25 31 81 36 49 57
# 8 47 21 44 74 49 41 68
# 16 49 29 47 78 57 46 71
# 18 51 27 45 71 50 45 61
# 18 52 28 46 77 49 48 63
# 13 48 25 42 76 49 43 65
# 2 44 11 40 66 46 24 67
# 22 51 36 45 82 50 61 67
# 6 40 13 34 60 39 24 56
# 16 39 28 34 75 41 47 58
# 24 41 36 34 78 41 59 58
# 13 51 25 44 71 48 44 65
# 5 50 14 43 69 48 31 66
# 23 50 37 43 81 48 62 65
# 7 42 16 34 67 40 33 58
# 19 37 31 32 82 39 54 56
# 23 36 31 30 73 38 50 53
# 32 41 43 35 82 43 66 58
# 13 35 24 31 79 38 45 56
# 21 35 33 29 84 36 55 54
# 14 34 24 28 77 36 43 53
# 18 37 27 33 76 39 46 56
# 17 38 27 33 73 39 44 54
# 13 37 22 30 73 38 38 54
# 13 33 22 24 78 33 42 45
# 18 59 31 54 81 51 54 73
# 4 55 15 51 69 56 32 73
# 5 52 14 49 65 56 27 71
# 17 57 32 53 83 52 55 73
# 17 58 30 54 81 55 52 75
# 17 55 31 51 81 55 53 72
# 13 56 26 52 79 56 47 73
# 20 57 34 50 85 48 61 68
# 10 54 21 48 74 52 41 69
# 13 56 24 51 76 53 45 73
# 17 40 29 32 78 42 49 55
# 16 43 27 34 78 42 49 56
# 23 44 38 37 86 49 63 63
# 15 46 25 40 76 49 44 68
# 17 39 28 31 77 42 46 53
# 17 44 27 37 77 47 47 61
# 14 38 25 27 76 42 45 48
# 15 49 26 45 75 53 45 70
# 6 43 14 35 69 48 29 60
# 16 41 28 33 79 43 48 56
# 11 44 19 37 69 45 37 61
# 12 42 21 35 71 43 39 59
# 12 48 22 42 74 47 42 64
# 14 48 22 44 68 49 38 67
# 14 51 24 46 74 50 42 68
# 18 52 29 46 77 49 50 68
# 5 48 11 46 58 52 23 69
# 13 45 22 39 73 44 42 62
# 8 47 15 43 66 50 30 67
# 15 50 26 44 76 48 46 67
# 3 42 11 38 69 38 30 64
# 14 40 30 38 86 52 52 69
# 17 36 35 36 87 50 55 66
# 5 41 15 39 69 40 32 65
# 10 49 23 47 78 55 41 72
# 2.pgm
# 4 39 11 36 65 32 29 60
# 5 48 14 45 71 43 33 67
# 12 43 28 41 85 51 49 70
# 4.pgm
# 5.pgm
# 14 43 25 34 84 40 47 52
# 17 41 30 34 79 48 50 55
# 13 48 23 39 73 42 46 56
# 14 47 25 39 74 44 47 57
# 2.pgm
# 13 48 24 39 76 44 46 58
# 10 45 22 37 77 43 46 55
# 14 47 26 39 81 42 47 58
# 4.pgm
# 4 45 12 40 64 48 26 62
# 10 50 23 45 77 54 43 68
# 8 50 19 45 70 55 34 69
# 24 48 37 42 83 49 60 64
# 17 49 30 43 79 52 51 66
# 26 48 39 43 84 51 62 65
# 16 50 28 43 79 50 50 66
# 18 48 31 41 81 48 55 64
# 8 51 19 45 72 53 37 69
# 7 45 16 40 68 52 30 64

# %%
import os
import numpy 
import cv2
from matplotlib import pyplot as plt
from PIL import Image

path="/home/arundhati/cv/dlib_project/look"
image_paths = [os.path.join(path, f) for f in os.listdir(path)]

for image_path in image_paths:
    #print image_path
    image_pil = Image.open(image_path).convert('L')
    image = numpy.array(image_pil, 'uint8')
    histr = cv2.calcHist([image],[0],None,[256],[0,256])
    plt.hist(image.ravel(),256,[0,256])
plt.show()
